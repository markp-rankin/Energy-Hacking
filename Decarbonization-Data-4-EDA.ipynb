# %% [markdown]
# ## Data 4: Smarthome Dataset
# Taking a look at some of the data from a recent hackathon on decarbonization.

# %%
# load some libraries and such
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# Increase column width to display df
pd.set_option('display.max_columns', None)

# Increases the size of sns plots
sns.set(rc={'figure.figsize':(12,10)})

# %%
# Load some data
df_A2016m2 = pd.read_csv('HomeA-meter2_2016.csv')

# print the shape and look at df
print("df_A2016m2:", df_A2016m2.shape)
df_A2016m2.head()
# Out:
# df_A2016m2: (246639, 14)
#            Date & Time  use [kW]  gen [kW]  FurnaceHRV [kW]  \
# 0  2016-01-01 00:00:00       0.0       0.0         0.084142
# 1  2016-01-01 00:30:00       0.0       0.0         0.009887
# 2  2016-01-01 01:00:00       0.0       0.0         0.044926
# 3  2016-01-01 01:30:00       0.0       0.0         0.037721
# 4  2016-01-01 02:00:00       0.0       0.0         0.010029
#
#    CellarOutlets [kW]  WashingMachine [kW]  FridgeRange [kW]  \
# 0            0.113495             0.000123          0.001031
# 1            0.028861             0.000007          0.001053
# 2            0.086999             0.000083          0.001052
# 3            0.049664             0.000064          0.001056
# 4            0.065564             0.000011          0.001069
#
#    DisposalDishwasher [kW]  KitchenLights [kW]  BedroomOutlets [kW]  \
# 0                 0.000067            0.000017             0.014268
# 1                 0.000021            0.000009             0.014318
# ...

# %%
df_A2016m2.tail()
# Out:
#                 Date & Time  use [kW]  gen [kW]  FurnaceHRV [kW]  \
# 246634  2016-12-31 23:55:00       0.0       0.0         0.086217
# 246635  2016-12-31 23:56:00       0.0       0.0         0.086217
# 246636  2016-12-31 23:57:00       0.0       0.0         0.086417
# 246637  2016-12-31 23:58:00       0.0       0.0         0.086200
# 246638  2016-12-31 23:59:00       0.0       0.0         0.086083
#
#         CellarOutlets [kW]  WashingMachine [kW]  FridgeRange [kW]  \
# 246634            0.114800             0.000083          0.001050
# 246635            0.114683             0.000100          0.001017
# 246636            0.114583             0.000083          0.001050
# 246637            0.114417             0.000083          0.001083
# 246638            0.114200             0.000083          0.001033
#
#         DisposalDishwasher [kW]  KitchenLights [kW]  BedroomOutlets [kW]  \
# 246634                      0.0            0.000017             0.004667
# ...

# %%
df_A2016m2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246639 entries, 0 to 246638
# Data columns (total 14 columns):
# Date & Time                246639 non-null object
# use [kW]                   246639 non-null float64
# gen [kW]                   246639 non-null float64
# FurnaceHRV [kW]            246639 non-null float64
# CellarOutlets [kW]         246639 non-null float64
# WashingMachine [kW]        246639 non-null float64
# FridgeRange [kW]           246639 non-null float64
# DisposalDishwasher [kW]    246639 non-null float64
# KitchenLights [kW]         246639 non-null float64
# BedroomOutlets [kW]        246639 non-null float64
# BedroomLights [kW]         246639 non-null float64
# MasterOutlets [kW]         246639 non-null float64
# MasterLights [kW]          246639 non-null float64
# DuctHeaterHRV [kW]         246639 non-null float64
# dtypes: float64(13), object(1)
# memory usage: 26.3+ MB

# %%
df_A2016m2.describe()
# Out:
#        use [kW]  gen [kW]  FurnaceHRV [kW]  CellarOutlets [kW]  \
# count  246639.0  246639.0    246639.000000       246639.000000
# mean        0.0       0.0         0.154952            0.082903
# std         0.0       0.0         0.213281            0.057872
# min         0.0       0.0         0.003162            0.006850
# 25%         0.0       0.0         0.009867            0.008800
# 50%         0.0       0.0         0.085900            0.113750
# 75%         0.0       0.0         0.155683            0.115883
# max         0.0       0.0         0.981883            0.533200
#
#        WashingMachine [kW]  FridgeRange [kW]  DisposalDishwasher [kW]  \
# count        246639.000000     246639.000000            246639.000000
# mean              0.000539          0.001224                 0.000144
# std               0.000844          0.009572                 0.000154
# min               0.000000          0.000000                 0.000000
# ...

# %%
# Load some data
df_A2016weather = pd.read_csv('homeA2016.csv')

# print the shape and look at df
print("df_A2016weather:", df_A2016weather.shape)
df_A2016weather.head()
# Out:
# df_A2016weather: (8760, 14)
#    temperature                 icon  humidity  visibility        summary  \
# 0        34.98          clear-night      0.63       10.00          Clear
# 1        34.82  partly-cloudy-night      0.64        9.88  Mostly Cloudy
# 2        34.07          clear-night      0.65       10.00          Clear
# 3        34.02          clear-night      0.67        9.93          Clear
# 4        34.00  partly-cloudy-night      0.68       10.00  Mostly Cloudy
#
#    apparentTemperature  pressure  windSpeed  cloudCover        time  \
# 0                27.95   1016.80       8.95         NaN  1451624400
# 1                27.36   1016.23       9.71        0.92  1451628000
# 2                27.58   1016.02       7.65         NaN  1451631600
# 3                28.55   1015.99       6.12         NaN  1451635200
# 4                27.42   1015.58       7.78        0.75  1451638800
#
#    windBearing  precipIntensity  dewPoint  precipProbability
# ...

# %%
df_A2016weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
# temperature            8760 non-null float64
# icon                   8760 non-null object
# humidity               8759 non-null float64
# visibility             8759 non-null float64
# summary                8760 non-null object
# apparentTemperature    8760 non-null float64
# pressure               8759 non-null float64
# windSpeed              8755 non-null float64
# cloudCover             7814 non-null float64
# time                   8760 non-null int64
# windBearing            8753 non-null float64
# precipIntensity        8760 non-null float64
# dewPoint               8759 non-null float64
# precipProbability      8760 non-null float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 958.2+ KB

# %%
df2_weather = df_A2016weather.sample(n=500)
df2_weather.shape
# Out:
# (500, 14)

# %%
# Do some basic charting - visibility and pressure
sns.scatterplot(data=df2_weather, x="pressure", y="visibility")
# Out:
# <AxesSubplot:xlabel='pressure', ylabel='visibility'>

# %%
sns.pairplot(df2_weather)
